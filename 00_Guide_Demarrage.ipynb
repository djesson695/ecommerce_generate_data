# %% [markdown]
# #  Guide de Démarrage - Système de Recommandation
#
# ## Bienvenue dans le TP !
#
# Ce notebook vous guidera pour bien démarrer le projet.

# %% [markdown]
# ##  Installation des Bibliothèques
#
# Commencez par installer toutes les bibliothèques nécessaires :

# %%
# Installation des bibliothèques (décommentez si nécessaire)
# !pip install pandas numpy matplotlib seaborn scikit-learn
# !pip install scipy mlflow fastapi uvicorn
# !pip install scikit-surprise  # Pour le filtrage collaboratif
# Out:
# Requirement already satisfied: pandas in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (2.0.2)
# Requirement already satisfied: matplotlib in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: seaborn in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: scipy>=1.6.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Requirement already satisfied: scipy in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (1.13.1)
# Collecting mlflow
#   Downloading mlflow-3.5.1-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: fastapi in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (0.114.1)
# Requirement already satisfied: uvicorn in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (0.30.6)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from scipy) (2.0.2)
# Collecting mlflow-skinny==3.5.1 (from mlflow)
#   Downloading mlflow_skinny-3.5.1-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.5.1 (from mlflow)
#   Downloading mlflow_tracing-3.5.1-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Downloading flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting Flask<4 (from mlflow)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.17.1-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow) (43.0.3)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Using cached gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: matplotlib<4 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow) (3.9.2)
# Requirement already satisfied: pandas<3 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow) (2.2.2)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow) (17.0.0)
# Requirement already satisfied: scikit-learn<2 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow) (1.5.1)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow)
#   Downloading sqlalchemy-2.0.44-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow-skinny==3.5.1->mlflow) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow-skinny==3.5.1->mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow-skinny==3.5.1->mlflow) (3.0.0)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading databricks_sdk-0.71.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow-skinny==3.5.1->mlflow) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow-skinny==3.5.1->mlflow) (8.4.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow-skinny==3.5.1->mlflow) (24.1)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow-skinny==3.5.1->mlflow) (4.25.4)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow-skinny==3.5.1->mlflow) (2.8.2)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow-skinny==3.5.1->mlflow) (1.0.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow-skinny==3.5.1->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow-skinny==3.5.1->mlflow) (2.32.3)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from mlflow-skinny==3.5.1->mlflow) (4.12.2)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from fastapi) (0.38.5)
# Requirement already satisfied: h11>=0.8 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from uvicorn) (0.14.0)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: cffi>=1.12 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from cryptography<47,>=43.0.0->mlflow) (1.17.0)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading google_auth-2.42.1-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow) (2.2.2)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from Flask<4->mlflow) (2.1.5)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.5.1->mlflow) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.5.1->mlflow) (5.0.1)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=0.5 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.5.1->mlflow) (3.20.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from matplotlib<4->mlflow) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from matplotlib<4->mlflow) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from matplotlib<4->mlflow) (3.1.4)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading protobuf-6.33.0-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.1->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.1->mlflow) (2.20.1)
# Requirement already satisfied: six>=1.5 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.1->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.1->mlflow) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.1->mlflow) (2024.8.30)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: joblib>=1.2.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from starlette<0.39.0,>=0.37.2->fastapi) (4.4.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from anyio<5,>=3.4.0->starlette<0.39.0,>=0.37.2->fastapi) (1.3.1)
# Requirement already satisfied: pycparser in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from cffi>=1.12->cryptography<47,>=43.0.0->mlflow) (2.22)
# Downloading mlflow-3.5.1-py3-none-any.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 13.2 MB/s eta 0:00:0000:0100:01
# Downloading mlflow_skinny-3.5.1-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 19.7 MB/s eta 0:00:00
# Downloading mlflow_tracing-3.5.1-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.9 MB/s eta 0:00:00
# Downloading alembic-1.17.1-py3-none-any.whl (247 kB)
# Downloading databricks_sdk-0.71.0-py3-none-any.whl (752 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 752.6/752.6 kB 15.4 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Downloading google_auth-2.42.1-py2.py3-none-any.whl (222 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
# Downloading protobuf-6.33.0-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading sqlalchemy-2.0.44-cp312-cp312-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 19.9 MB/s eta 0:00:00
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Installing collected packages: werkzeug, sqlparse, sqlalchemy, pyasn1, protobuf, Mako, gunicorn, graphql-core, blinker, rsa, pyasn1-modules, opentelemetry-proto, opentelemetry-api, graphql-relay, Flask, docker, alembic, opentelemetry-semantic-conventions, graphene, google-auth, Flask-CORS, opentelemetry-sdk, databricks-sdk, mlflow-tracing, mlflow-skinny, mlflow
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.0.4
#     Uninstalling Werkzeug-3.0.4:
#       Successfully uninstalled Werkzeug-3.0.4
#   Attempting uninstall: protobuf━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/26 [sqlalchemy]
#     Found existing installation: protobuf 4.25.4━━━━━━━━━━━━━━  2/26 [sqlalchemy]
#     Uninstalling protobuf-4.25.4:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/26 [sqlalchemy]
#       Successfully uninstalled protobuf-4.25.4━━━━━━━━━━━━━━━━  2/26 [sqlalchemy]
#   Attempting uninstall: blinkerm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/26 [graphql-core]
#     Found existing installation: blinker 1.8.2━━━━━━━━━━━━━━━━  7/26 [graphql-core]
#     Uninstalling blinker-1.8.2:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/26 [graphql-core]
#       Successfully uninstalled blinker-1.8.2━━━━━━━━━━━━━━━━━━  7/26 [graphql-core]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26/26 [mlflow]25/26 [mlflow]skinny]]c-conventions]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.0 which is incompatible.
# streamlit 1.38.0 requires protobuf<6,>=3.20, but you have protobuf 6.33.0 which is incompatible.
# tensorflow-macos 2.16.2 requires tensorflow==2.16.2; platform_system == "Darwin" and platform_machine == "arm64", but you have tensorflow 2.18.0 which is incompatible.
# Successfully installed Flask-3.1.2 Flask-CORS-6.0.1 Mako-1.3.10 alembic-1.17.1 blinker-1.9.0 databricks-sdk-0.71.0 docker-7.1.0 google-auth-2.42.1 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 gunicorn-23.0.0 mlflow-3.5.1 mlflow-skinny-3.5.1 mlflow-tracing-3.5.1 opentelemetry-api-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 protobuf-6.33.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1 sqlalchemy-2.0.44 sqlparse-0.5.3 werkzeug-3.1.3
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Collecting scikit-surprise
#   Downloading scikit_surprise-1.1.4.tar.gz (154 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib>=1.2.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from scikit-surprise) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from scikit-surprise) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/djessim.djb/.pyenv/versions/lewagon/lib/python3.12/site-packages (from scikit-surprise) (1.13.1)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (pyproject.toml) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp312-cp312-macosx_13_0_arm64.whl size=496108 sha256=4d4b579844f6525d5c782e9e5ad91177fa999058dc9ecacbc19cc8cee2716ec1
#   Stored in directory: /Users/djessim.djb/Library/Caches/pip/wheels/75/fa/bc/739bc2cb1fbaab6061854e6cfbb81a0ae52c92a502a7fa454b
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.4
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip

# %% [markdown]
# ##  Imports de Base

# %%
# Manipulation de données
import pandas as pd
import numpy as np

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.ensemble import RandomForestClassifier

# Configuration
import warnings
warnings.filterwarnings('ignore')

# Style des graphiques
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print(" Imports réussis !")
# Out:
#  Imports réussis !

# %% [markdown]
# ##  Génération des Données
#
# Exécutez le script de génération de donné

# %%
# Générer les données synthétiques
# %run ../data/generate_data.py
# Out:
# 🔧 Génération des données synthétiques en cours...
#    Utilisateurs : 5000
#    Produits : 1000
#    Interactions : 50000
#
# 👥 Génération des utilisateurs...
#    ✅ 5000 utilisateurs créés
# 📦 Génération des produits...
#    ✅ 1000 produits créés
# 🔗 Génération des interactions...
#    ✅ 50000 interactions créées
# 🔧 Ajout de données complémentaires...
#
# 📊 Statistiques des données générées :
#    Utilisateurs : 5000
#    Produits : 1000
#    Interactions : 50000
#
#    Distribution des interactions :
# interaction_type
# view           34965
# add_to_cart    10034
# purchase        3988
# review          1013
# Name: count, dtype: int64
#
#    Distribution des catégories de produits :
# category
# Accessoires    175
# Ordinateurs    150
# Smartphones    133
# Gaming         128
# Audio          103
# Name: count, dtype: int64
#
# 💾 Sauvegarde des fichiers...
#    ✅ users.csv créé
#    ✅ products.csv créé
#    ✅ interactions.csv créé
#    ✅ metadata.json créé
#
# ✅ Génération terminée avec succès !
#
# 📁 Fichiers créés :
#    - users.csv
#    - products.csv
#    - interactions.csv
#    - metadata.json
#
# 🚀 Vous pouvez maintenant commencer le TP !

# %% [markdown]
# ##  Prochaines Étapes
#
# 1. Les données sont maintenant générées dans le dossier `data/`
# 2. Vous pouvez passer au notebook `01_EDA.ipynb` pour l'analyse exploratoire
# 3. Suivez les instructions du sujet étape par étape
#
#
# Bon courage !
